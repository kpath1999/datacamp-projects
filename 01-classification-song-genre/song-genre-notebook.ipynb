# %% [markdown]
# ## 1. Preparing our dataset
# <p><em>These recommendations are so on point! How does this playlist know me so well?</em></p>
# <p><img src="original-music.avif" alt="Project Image Record" width="600px"></p>
# <p>Over the past few years, streaming services with huge catalogs have become the primary means through which most people listen to their favorite music. But at the same time, the sheer amount of music on offer can mean users might be a bit overwhelmed when trying to look for newer music that suits their tastes.</p>
# <p>For this reason, streaming services have looked into means of categorizing music to allow for personalized recommendations. One method involves direct analysis of the raw audio information in a given song, scoring the raw data on a variety of metrics. Today, we'll be examining data compiled by a research group known as The Echo Nest. Our goal is to look through this dataset and classify songs as being either 'Hip-Hop' or 'Rock' - all without listening to a single one ourselves. In doing so, we will learn how to clean our data, do some exploratory data visualization, and use feature reduction towards the goal of feeding our data through some simple machine learning algorithms, such as decision trees and logistic regression.</p>
# <p>To begin with, let's load the metadata about our tracks alongside the track metrics compiled by The Echo Nest. A song is about more than its title, artist, and number of listens. We have another dataset that has musical features of each track such as <code>danceability</code> and <code>acousticness</code> on a scale from -1 to 1. These exist in two different files, which are in different formats - CSV and JSON. While CSV is a popular file format for denoting tabular data, JSON is another common file format in which databases often return the results of a given query.</p>
# <p>Let's start by creating two pandas <code>DataFrames</code> out of these files that we can merge so we have features and labels (often also referred to as <code>X</code> and <code>y</code>) for the classification later on.</p>

# %%
import pandas as pd

# Reading in the 2 data sources
tracks = pd.read_csv('datasets/fma-rock-vs-hiphop.csv')
echonest_metrics = pd.read_json('datasets/echonest-metrics.json', precise_float=True)

# %%
tracks.head(3)
# Out:
#    track_id  bit_rate  comments composer         date_created  \
# 0       135    256000         1      NaN  2008-11-26 01:43:26
# 1       136    256000         1      NaN  2008-11-26 01:43:35
# 2       151    192000         0      NaN  2008-11-26 01:44:55
#
#          date_recorded  duration  favorites genre_top    genres  ...  \
# 0  2008-11-26 00:00:00       837          0      Rock  [45, 58]  ...
# 1  2008-11-26 00:00:00       509          0      Rock  [45, 58]  ...
# 2                  NaN       192          0      Rock      [25]  ...
#
#   information interest  language_code  \
# 0         NaN     2484             en
# 1         NaN     1948             en
# 2         NaN      701             en
#
#                                              license listens  lyricist number  \
# 0  Attribution-NonCommercial-ShareAlike 3.0 Inter...    1832       NaN      0
# 1  Attribution-NonCommercial-ShareAlike 3.0 Inter...    1498       NaN      0
# 2  Attribution-NonCommercial-ShareAlike 3.0 Inter...     148       NaN      4
#
#    publisher tags                       title
# 0        NaN   []                Father's Day
# 1        NaN   []  Peel Back The Mountain Sky
# 2        NaN   []                 Untitled 04
#
# [3 rows x 21 columns]

# %%
# Only considering "track_id" and "genre_top" in the tracks dataset
tracks_append = tracks[['track_id', 'genre_top']]
tracks_append.head()
# Out:
#    track_id genre_top
# 0       135      Rock
# 1       136      Rock
# 2       151      Rock
# 3       152      Rock
# 4       153      Rock

# %%
echonest_metrics.head()
# Out:
#       track_id  acousticness  danceability    energy  instrumentalness  \
# 0            2      0.416675      0.675894  0.634476          0.010628
# 1            3      0.374408      0.528643  0.817461          0.001851
# 10         145      0.235506      0.438672  0.487752          0.716122
# 100        341      0.977282      0.468808  0.134975          0.687700
# 1000      3457      0.081256      0.897197  0.367886          0.104474
#
#       liveness  speechiness    tempo   valence
# 0     0.177647     0.159310  165.922  0.576661
# 1     0.105880     0.461818  126.957  0.269240
# 10    0.070359     0.047298  120.790  0.650452
# 100   0.105381     0.073124  119.646  0.430707
# 1000  0.085845     0.041271  100.744  0.749293

# %%
# Merging the 2 datasets, using the track_id as the common column
echo_tracks = echonest_metrics.merge(tracks_append, on='track_id')

# Inspecting the new dataset
echo_tracks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4802 entries, 0 to 4801
# Data columns (total 10 columns):
# track_id            4802 non-null int64
# acousticness        4802 non-null float64
# danceability        4802 non-null float64
# energy              4802 non-null float64
# instrumentalness    4802 non-null float64
# liveness            4802 non-null float64
# speechiness         4802 non-null float64
# tempo               4802 non-null float64
# valence             4802 non-null float64
# genre_top           4802 non-null object
# dtypes: float64(8), int64(1), object(1)
# memory usage: 412.7+ KB

# %% [markdown]
# ## 2. Pairwise relationships between continuous variables
# <p>We typically want to avoid using variables that have strong correlations with each other -- hence avoiding feature redundancy -- for a few reasons:</p>
# <ul>
# <li>To keep the model simple and improve interpretability (with many features, we run the risk of overfitting).</li>
# <li>When our datasets are very large, using fewer features can drastically speed up our computation time.</li>
# </ul>
# <p>To get a sense of whether there are any strongly correlated features in our data, we will use built-in functions in the <code>pandas</code> package.</p>

# %%
# Creating a correlation matrix
corr_metrics = echo_tracks.corr()
corr_metrics.style.background_gradient()
# Out:
# <style  type="text/css" >
#     #T_b3ec6c0a_a3db_11ee_8ce6_9cb6d094e664row0_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_b3ec6c0a_a3db_11ee_8ce6_9cb6d094e664row0_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_b3ec6c0a_a3db_11ee_8ce6_9cb6d094e664row0_col2 {
#             background-color:  #d2d2e7;
#             color:  #000000;
#         }    #T_b3ec6c0a_a3db_11ee_8ce6_9cb6d094e664row0_col3 {
#             background-color:  #b5c4df;
#             color:  #000000;
#         }    #T_b3ec6c0a_a3db_11ee_8ce6_9cb6d094e664row0_col4 {
#             background-color:  #f5eef6;
#             color:  #000000;
#         }    #T_b3ec6c0a_a3db_11ee_8ce6_9cb6d094e664row0_col5 {
#             background-color:  #e9e5f1;
#             color:  #000000;
#         }    #T_b3ec6c0a_a3db_11ee_8ce6_9cb6d094e664row0_col6 {
#             background-color:  #d1d2e6;
#             color:  #000000;
#         }    #T_b3ec6c0a_a3db_11ee_8ce6_9cb6d094e664row0_col7 {
#             background-color:  #e1dfed;
#             color:  #000000;
#         }    #T_b3ec6c0a_a3db_11ee_8ce6_9cb6d094e664row0_col8 {
#             background-color:  #dedcec;
#             color:  #000000;
#         }    #T_b3ec6c0a_a3db_11ee_8ce6_9cb6d094e664row1_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_b3ec6c0a_a3db_11ee_8ce6_9cb6d094e664row1_col1 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_b3ec6c0a_a3db_11ee_8ce6_9cb6d094e664row1_col2 {
#             background-color:  #e0dded;
#             color:  #000000;
#         }    #T_b3ec6c0a_a3db_11ee_8ce6_9cb6d094e664row1_col3 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_b3ec6c0a_a3db_11ee_8ce6_9cb6d094e664row1_col4 {
#             background-color:  #97b7d7;
#             color:  #000000;
#         }    #T_b3ec6c0a_a3db_11ee_8ce6_9cb6d094e664row1_col5 {
#             background-color:  #f3edf5;
#             color:  #000000;
#         }    #T_b3ec6c0a_a3db_11ee_8ce6_9cb6d094e664row1_col6 {
#             background-color:  #b8c6e0;
#             color:  #000000;
#         }    #T_b3ec6c0a_a3db_11ee_8ce6_9cb6d094e664row1_col7 {
#             background-color:  #e1dfed;
#             color:  #000000;
#         }    #T_b3ec6c0a_a3db_11ee_8ce6_9cb6d094e664row1_col8 {
#             background-color:  #e2dfee;
#             color:  #000000;
#         }    #T_b3ec6c0a_a3db_11ee_8ce6_9cb6d094e664row2_col0 {
#             background-color:  #bdc8e1;
#             color:  #000000;
#         }    #T_b3ec6c0a_a3db_11ee_8ce6_9cb6d094e664row2_col1 {
#             background-color:  #d0d1e6;
#             color:  #000000;
#         }    #T_b3ec6c0a_a3db_11ee_8ce6_9cb6d094e664row2_col2 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_b3ec6c0a_a3db_11ee_8ce6_9cb6d094e664row2_col3 {
#             background-color:  #fbf3f9;
#             color:  #000000;
#         }    #T_b3ec6c0a_a3db_11ee_8ce6_9cb6d094e664row2_col4 {
#             background-color:  #f3edf5;
#             color:  #000000;
#         }    #T_b3ec6c0a_a3db_11ee_8ce6_9cb6d094e664row2_col5 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_b3ec6c0a_a3db_11ee_8ce6_9cb6d094e664row2_col6 {
#             background-color:  #80aed2;
#             color:  #000000;
#         }    #T_b3ec6c0a_a3db_11ee_8ce6_9cb6d094e664row2_col7 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_b3ec6c0a_a3db_11ee_8ce6_9cb6d094e664row2_col8 {
#             background-color:  #529bc7;
#             color:  #000000;
#         }    #T_b3ec6c0a_a3db_11ee_8ce6_9cb6d094e664row3_col0 {
#             background-color:  #a7bddb;
#             color:  #000000;
#         }    #T_b3ec6c0a_a3db_11ee_8ce6_9cb6d094e664row3_col1 {
#             background-color:  #f5eff6;
#             color:  #000000;
#         }    #T_b3ec6c0a_a3db_11ee_8ce6_9cb6d094e664row3_col2 {
#             background-color:  #fef6fa;
#             color:  #000000;
#         }    #T_b3ec6c0a_a3db_11ee_8ce6_9cb6d094e664row3_col3 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_b3ec6c0a_a3db_11ee_8ce6_9cb6d094e664row3_col4 {
#             background-color:  #c4cbe3;
#             color:  #000000;
#         }    #T_b3ec6c0a_a3db_11ee_8ce6_9cb6d094e664row3_col5 {
#             background-color:  #dcdaeb;
#             color:  #000000;
#         }    #T_b3ec6c0a_a3db_11ee_8ce6_9cb6d094e664row3_col6 {
#             background-color:  #dedcec;
#             color:  #000000;
#         }    #T_b3ec6c0a_a3db_11ee_8ce6_9cb6d094e664row3_col7 {
#             background-color:  #adc1dd;
#             color:  #000000;
#         }    #T_b3ec6c0a_a3db_11ee_8ce6_9cb6d094e664row3_col8 {
#             background-color:  #d9d8ea;
#             color:  #000000;
#         }    #T_b3ec6c0a_a3db_11ee_8ce6_9cb6d094e664row4_col0 {
#             background-color:  #f4eef6;
#             color:  #000000;
#         }    #T_b3ec6c0a_a3db_11ee_8ce6_9cb6d094e664row4_col1 {
#             background-color:  #97b7d7;
#             color:  #000000;
#         }    #T_b3ec6c0a_a3db_11ee_8ce6_9cb6d094e664row4_col2 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_b3ec6c0a_a3db_11ee_8ce6_9cb6d094e664row4_col3 {
#             background-color:  #d2d3e7;
#             color:  #000000;
#         }    #T_b3ec6c0a_a3db_11ee_8ce6_9cb6d094e664row4_col4 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_b3ec6c0a_a3db_11ee_8ce6_9cb6d094e664row4_col5 {
#             background-color:  #fdf5fa;
#             color:  #000000;
#         }    #T_b3ec6c0a_a3db_11ee_8ce6_9cb6d094e664row4_col6 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_b3ec6c0a_a3db_11ee_8ce6_9cb6d094e664row4_col7 {
#             background-color:  #d9d8ea;
#             color:  #000000;
#         }    #T_b3ec6c0a_a3db_11ee_8ce6_9cb6d094e664row4_col8 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_b3ec6c0a_a3db_11ee_8ce6_9cb6d094e664row5_col0 {
#             background-color:  #bdc8e1;
#             color:  #000000;
#         }    #T_b3ec6c0a_a3db_11ee_8ce6_9cb6d094e664row5_col1 {
#             background-color:  #ced0e6;
#             color:  #000000;
#         }    #T_b3ec6c0a_a3db_11ee_8ce6_9cb6d094e664row5_col2 {
#             background-color:  #ede8f3;
#             color:  #000000;
#         }    #T_b3ec6c0a_a3db_11ee_8ce6_9cb6d094e664row5_col3 {
#             background-color:  #bdc8e1;
#             color:  #000000;
#         }    #T_b3ec6c0a_a3db_11ee_8ce6_9cb6d094e664row5_col4 {
#             background-color:  #dbdaeb;
#             color:  #000000;
#         }    #T_b3ec6c0a_a3db_11ee_8ce6_9cb6d094e664row5_col5 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_b3ec6c0a_a3db_11ee_8ce6_9cb6d094e664row5_col6 {
#             background-color:  #c0c9e2;
#             color:  #000000;
#         }    #T_b3ec6c0a_a3db_11ee_8ce6_9cb6d094e664row5_col7 {
#             background-color:  #dcdaeb;
#             color:  #000000;
#         }    #T_b3ec6c0a_a3db_11ee_8ce6_9cb6d094e664row5_col8 {
#             background-color:  #e8e4f0;
#             color:  #000000;
#         }    #T_b3ec6c0a_a3db_11ee_8ce6_9cb6d094e664row6_col0 {
#             background-color:  #d0d1e6;
#             color:  #000000;
#         }    #T_b3ec6c0a_a3db_11ee_8ce6_9cb6d094e664row6_col1 {
#             background-color:  #b8c6e0;
#             color:  #000000;
#         }    #T_b3ec6c0a_a3db_11ee_8ce6_9cb6d094e664row6_col2 {
#             background-color:  #93b5d6;
#             color:  #000000;
#         }    #T_b3ec6c0a_a3db_11ee_8ce6_9cb6d094e664row6_col3 {
#             background-color:  #eae6f1;
#             color:  #000000;
#         }    #T_b3ec6c0a_a3db_11ee_8ce6_9cb6d094e664row6_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_b3ec6c0a_a3db_11ee_8ce6_9cb6d094e664row6_col5 {
#             background-color:  #eae6f1;
#             color:  #000000;

# %% [markdown]
# ## 3. Splitting our data
# <p>As mentioned earlier, it can be particularly useful to simplify our models and use as few features as necessary to achieve the best result. Since we didn't find any particularly strong correlations between our features, we can now split our data into an array containing our features, and another containing the labels - the genre of the track. </p>
# <p>Once we have split the data into these arrays, we will perform some preprocessing steps to optimize our model development.</p>

# %%
# Import the train_test_split function
from sklearn.model_selection import train_test_split

# Creating features
features = echo_tracks.drop(['genre_top', 'track_id'], axis=1).values

# Creating labels
labels = echo_tracks['genre_top'].values

# Splitting the dataset
# Random state = controls the shuffling applied to the data before applying the split
train_features, test_features, train_labels, test_labels = train_test_split(features, labels, random_state=10)

# %% [markdown]
# ## 4. Normalizing the feature data
# <p>As mentioned earlier, it can be particularly useful to simplify our models and use as few features as necessary to achieve the best result. Since we didn't find any particular strong correlations between our features, we can instead use a common approach to reduce the number of features called <strong>principal component analysis (PCA)</strong>. </p>
# <p>It is possible that the variance between genres can be explained by just a few features in the dataset. PCA rotates the data along the axis of highest variance, thus allowing us to determine the relative contribution of each feature of our data towards the variance between classes. </p>
# <p>However, since PCA uses the absolute variance of a feature to rotate the data, a feature with a broader range of values will overpower and bias the algorithm relative to the other features. To avoid this, we must first normalize our train and test features. There are a few methods to do this, but a common way is through <em>standardization</em>, such that all features have a mean = 0 and standard deviation = 1 (the resultant is a z-score). </p>

# %%
# Importing the StandardScaler
from sklearn.preprocessing import StandardScaler

# Scaling the train and test features
scaler = StandardScaler()
scaled_train_features = scaler.fit_transform(train_features)
scaled_test_features = scaler.transform(test_features)

# %% [markdown]
# ## 5. Principal Component Analysis on our scaled data
# <p>Now that we have preprocessed our data, we are ready to use PCA to determine by how much we can reduce the dimensionality of our data. We can use <strong>scree-plots</strong> and <strong>cumulative explained ratio plots</strong> to find the number of components to use in further analyses.</p>
# <p>Scree-plots display the number of components against the variance explained by each component, sorted in descending order of variance. Scree-plots help us get a better sense of which components explain a sufficient amount of variance in our data. When using scree plots, an 'elbow' (a steep drop from one data point to the next) in the plot is typically used to decide on an appropriate cutoff.</p>

# %%
# Makes sure the plots appear in the notebook
# %matplotlib inline

# Importing the plotting module and the PCA class
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA

# Get the explained variance ratios from PCA using all features
pca = PCA()
pca.fit(scaled_train_features)
exp_variance = pca.explained_variance_ratio_

# Plot the explained variance using a barplot
fig, ax = plt.subplots()
ax.bar(range(pca.n_components_), exp_variance)
ax.set_xlabel('Principal Component #')
# Out:
# Text(0.5, 0, 'Principal Component #')

# %% [markdown]
# ## 6. Further visualization of PCA
# <p>There does not appear to be a clear elbow in this scree plot, which means it is not straightforward to find the number of intrinsic dimensions using this method. </p>
# <p>We can also look at the <strong>cumulative explained variance plot</strong> to determine how many features are required to explain, say, about 85% of the variance (cutoffs are somewhat arbitrary here, and usually decided upon by 'rules of thumb'). Once we determine the appropriate number of components, we can perform PCA with that many components, ideally reducing the dimensionality of our data.</p>

# %%
import numpy as np

# Calculate the cumulative explained variance
cum_exp_variance = np.cumsum(exp_variance)

# Plot the cumulative explained variance and draw a dashed line at 0.85
fig, ax = plt.subplots()
ax.plot(cum_exp_variance)
ax.axhline(y=0.85, linestyle='--')

# %% [markdown]
# ## 7. Projecting on to our features
# <p>We saw from the plot that 6 features (indexing starts at 0) can explain 85% of the variance! </p>
# <p>Therefore, we can use 6 components to perform PCA and reduce the dimensionality of our train and test features.</p>

# %%
# Perform PCA with the 6 components and project data onto the components
pca = PCA(n_components=6, random_state=10)

# Fit and transform the scaled training features
train_pca = pca.fit_transform(scaled_train_features)

# Tranform the scaled test features
test_pca = pca.transform(scaled_test_features)

# %% [markdown]
# ## 8. Train a decision tree to classify genre
# <p>Now we can use the lower dimensional PCA projection of the data to classify songs into genres. </p>
# <p>Here, we will be using a simple algorithm known as a decision tree. Decision trees are rule-based classifiers that take in features and follow a 'tree structure' of binary decisions to ultimately classify a data point into one of two or more categories. In addition to being easy to both use and interpret, decision trees allow us to visualize the 'logic flowchart' that the model generates from the training data.</p>

# %%
# Import the decision tree classifier
from sklearn.tree import DecisionTreeClassifier

# Train the decision tree
tree = DecisionTreeClassifier(random_state=10)
tree.fit(train_pca, train_labels)

# Predict the labels for the test data
pred_labels_tree = tree.predict(test_pca)
